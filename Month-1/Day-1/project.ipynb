# %%
Jahez_order =[[150,110,140,135,120],[105,85,100,95,90],[125,100,120,115,110]]
print("=================================================")
print("  📊 تقرير أداء تطبيق جاهز - فروع منطقة الرياض")
print("=================================================")
print(f"📍 بيانات فرع العليا   (الصف 0): {Jahez_order[0]}")
print(f"📍 بيانات فرع الملز  (الصف 1): {Jahez_order[1]}")
print(f"📍 بيانات فرع الياسمين   (الصف 2): {Jahez_order[2]}")
print("---------------------------------------------------")
print("💡 ملاحظة المحلل: تم بنجاح هيكلة المصفوفة الرقمية\n   التي تعكس حجم الطلبات اليومية في العاصمة الرياض.")
# Out:
# ...
#   📊 تقرير أداء تطبيق جاهز - فروع منطقة الرياض
# ...
# 📍 بيانات فرع العليا   (الصف 0): [150, 110, 140, 135, 120]
# 📍 بيانات فرع الملز  (الصف 1): [105, 85, 100, 95, 90]
# 📍 بيانات فرع الياسمين   (الصف 2): [125, 100, 120, 115, 110]
# ---------------------------------------------------
# 💡 ملاحظة المحلل: تم بنجاح هيكلة المصفوفة الرقمية
#    التي تعكس حجم الطلبات اليومية في العاصمة الرياض.

# %% [markdown]
# ​إجمالي الأداء: تم تحليل حجم الطلبات اليومية لفروع تطبيق "جاهز" في منطقة الرياض للتأكد من كفاءة التوزيع.
#
# ​الفرع الأعلى: يتبين من الأرقام أن "فرع العليا" هو الأعلى تشغيلاً وبفارق كبير، مما يعكس ضغطاً على سائقي
# التوصيل في هذه المنطقة.
#
# ​الفرع الأقل: في المقابل، يمثل "فرع الملز" الأقل في حجم الطلبات اليومية، مما يشير إلى ركود نسبي في المنطقة.
#
# ​الملاحظة العامة: هناك استقرار واضح في حجم الطلبات بـ "فرع الياسمين" طوال أيام الأسبوع.
#
# ​التوصية: نقترح نقل جزء من أسطول التوصيل من فرع الملز لدعم فرع العليا لتغطية الضغط، مع عمل عروض ترويجية مخصصة لـ "منطقة الملز" لتنشيط المبيعات هناك.
