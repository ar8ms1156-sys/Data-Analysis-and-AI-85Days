# %%
jahez_orders =[[150,110,140,135,120],[105,85,100,95,90],[125,100,120,115,110]]
olaya_branch = jahez_orders[0]
malaz_branch = jahez_orders[1]
yasmin_branch = jahez_orders[2]
print("Olaya Data:", olaya_branch)
print("Malaz Data:", malaz_branch)
print("Yasmin Data:", yasmin_branch)
# Out:
# Olaya Data: [150, 110, 140, 135, 120]
# Malaz Data: [105, 85, 100, 95, 90]
# Yasmin Data: [125, 100, 120, 115, 110]

# %% [markdown]
# <div dir="rtl">
#
# # <center> 📊 تقرير أداء تطبيق جاهز — فروع منطقة الرياض </center>
#
# ---
#
# ### 📍 البيانات المهيكلة للمصفوفة الرقمية:
#
# * **بيانات فرع العليا:** `[150, 110, 140, 135, 120]`
# * **بيانات فرع الملز:** `[105, 85, 100, 95, 90]`
# * **بيانات فرع الياسمين:** `[125, 100, 120, 115, 110]`
#
# 💡 **ملاحظة المحلل:** تم بنجاح هيكلة المصفوفة الرقمية التي تعكس حجم الطلبات اليومية في العاصمة الرياض طوال أيام الأسبوع.
#
# ---
#
# ### 🔍 إجمالي الأداء والتحليل البيزنس:
#
# تم تحليل حجم الطلبات اليومية لفروع تطبيق "جاهز" في منطقة الرياض للتأكد من كفاءة التوزيع:
#
# * **الفرع الأعلى:** يتبين من الأرقام أن فرع العليا هو الأعلى تشغيلياً وبفارق كبير، مما يعكس ضغطاً مستمراً على سائقي التوصيل في هذه المنطقة.
# * **الفرع الأقل:** في المقابل، يمثل فرع الملز الأقل في حجم الطلبات اليومية، مما يشير إلى ركود نسبي في المنطقة.
# * **الملاحظة العامة:** هناك استقرار واضح في حجم الطلبات بـ فرع الياسمين طوال أيام الأسبوع.
#
# 🚀 **التوصية:** نقترح نقل جزء من أسطول التوصيل من فرع الملز لدعم فرع العليا لتغطية الضغط، مع عمل عروض ترويجية مخصصة لـ منطقة الملز لتنشيط المبيعات هناك.
#
# </div>
