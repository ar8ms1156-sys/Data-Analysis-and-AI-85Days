# %%
customers=[
    {"name":"أحمد","payment_method":"Urpay"},
    {"name":"خالد","payment_method":"visa"},
    {"name":"سارة","payment_method":"Urpay"}
]
for customer in customers:
    print(f"أهلاً بك يا {customer["name"]} في متجرنا!")
    if customer["payment_method"] == "Urpay":
        print("🎁 عرض خاص: لأنك تستخدم محفظة Urpay، حصلت على خصم 15% على طلبك اليوم!")
    else:
        print("نتمنى لك تجربة تسوق ممتعة معنا.")
        
    print("-" * 40)
# Out:
# أهلاً بك يا أحمد في متجرنا!
# 🎁 عرض خاص: لأنك تستخدم محفظة Urpay، حصلت على خصم 15% على طلبك اليوم!
# ----------------------------------------
# أهلاً بك يا خالد في متجرنا!
# نتمنى لك تجربة تسوق ممتعة معنا.
# ----------------------------------------
# أهلاً بك يا سارة في متجرنا!
# 🎁 عرض خاص: لأنك تستخدم محفظة Urpay، حصلت على خصم 15% على طلبك اليوم!
# ----------------------------------------

# %% [markdown]
# <div dir="rtl">
#
# <div dir="rtl">
#
# # <center> 📱 تقرير برنامج الترحيب الذكي وتخصيص العروض لعملاء محفظة Urpay — اليوم السادس </center>
#
# ---
#
# ### 💡 البيانات التشغيلية للنموذج (Features):
#
# * **قائمة العملاء المستهدفة (Customers List):** مصفوفة ديناميكية تحتوي على هويات العملاء وطرق الدفع الخاصة بهم.
# * **محفظة Urpay الرقمية:** المتغير الشرطي الأساسي والمؤهل للحصول على الخصم الحصري بنسبة 15%.
# * **قنوات الدفع البديلة (مثل Visa):** المتغير الشرطي التوجيهي لرسائل الترحيب العامة دون خصومات مالية.
#
# بنجاح تم بناء نموذج فرز العملاء الذكي وتجربته برمجياً باستخدام الحلقات التكرارية (Loops) والمتغيرات (Variables) على 3 حالات اختبارية للتأكد من دقة المنطق البرمجي والحسابات التسويقية.
#
# ---
#
# ### 🔍 إجمالي الأداء والتحليل المالي للبيزنس
#
# > **ملاحظة المحلل:** تم تحليل مخرجات برنامج الترحيب وتخصيص العروض لعملاء المتجر للتأكد من كفاءة الاستهداف وزيادة الولاء عبر المحافظ الرقمية، وأظهر البرنامج استجابة فورية ودقيقة بنسبة 100% في فرز العملاء وتطبيق الشروط البيعية المستهدفة تلقائياً دون أي تداخل في المخرجات.
#
# * **تأثير محفظة Urpay:** نجح الشرط البرمجي في رصد العملاء المؤهلين ("أحمد" و "سارة") ومنحهم خصم الـ 15% المخصص فوراً لتحفيز الدفع الرقمي عبر الشريك الاستراتيجي.
# * **تأثير طرق الدفع البديلة:** تم توجيه عملاء الوسائل الأخرى (مثل "خالد" مستخدم بطاقة Visa) لرسالة ترحيبية عامة وممتازة تحافظ على تجربة المستخدم الفريدة وتضمن استمرارية التسوق.
# * **كفاءة التكرار والفرز:** بفضل حلقة `for loop`، تم تنظيم المخرجات وفصلها بخطوط تنظيمية واضحة لضمان Scannability عالية ومظهر احترافي عند العرض.
#
# ---
#
# ### 🚀 التوصية
#
# نقترح اعتماد هذا النموذج البرمجي الذكي في نظام الكاشير أو بوابات الدفع للمتجر تلقائياً، مع إمكانية ربطه مستقبلاً بقاعدة بيانات حية (Database) للعملاء لتسهيل إرسال إشعارات العروض المخصصة لآلاف المستخدمين دفعة واحدة بدلاف من الحساب الفردي.
#
# </div>
